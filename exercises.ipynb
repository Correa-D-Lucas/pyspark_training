# %% [markdown]
# # Exercises

# %% [markdown]
# ## Module 1

# %% [markdown]
# 1. Create a SparkSession
# 2. Read employees.csv with header=True
# 3. Read employees.csv with inferSchema=True
# 4. Read sales.csv
# 5. Read multiple CSV files together
# 6. Create DataFrame manually
# 7. Define schema manually
# 8. Display first 5 rows
# 9. Print schema
# 10. Show distinct departments

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("exercices")
    .master("local[*]")
    .getOrCreate()
)

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://e02226551e85:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>exercices</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# 2. Read employees.csv with header=True
df_employees = spark.read.options(header=True).csv("datasets/employees.csv")
df_employees.show()
# Out:
# +-----------+----------+-------------+------+----------+
# |employee_id|first_name|department_id|salary| hire_date|
# +-----------+----------+-------------+------+----------+
# |          1|     Lucas|           10|  5000|2022-01-10|
# |          2|       Ana|           20|  7000|2021-03-15|
# |          3|    Carlos|           10|  4500|2023-06-01|
# |          4|     Maria|           30|  8000|2020-08-20|
# |          5|      Joao|           20|  6200|2022-11-11|
# |          6|  Fernanda|           30|  7200|2019-07-07|
# |          7|     Pedro|           10|  5100|2024-01-05|
# |          8|     Julia|           20|  6800|2021-12-12|
# +-----------+----------+-------------+------+----------+

# %%
# 3. Read employees.csv with inferSchema=True
df_employees_inferschema = spark.read.options(inferSchema=True,header=True).csv("datasets/employees.csv")
df_employees_inferschema.show()
# Out:
# +-----------+----------+-------------+------+----------+
# |employee_id|first_name|department_id|salary| hire_date|
# +-----------+----------+-------------+------+----------+
# |          1|     Lucas|           10|  5000|2022-01-10|
# |          2|       Ana|           20|  7000|2021-03-15|
# |          3|    Carlos|           10|  4500|2023-06-01|
# |          4|     Maria|           30|  8000|2020-08-20|
# |          5|      Joao|           20|  6200|2022-11-11|
# |          6|  Fernanda|           30|  7200|2019-07-07|
# |          7|     Pedro|           10|  5100|2024-01-05|
# |          8|     Julia|           20|  6800|2021-12-12|
# +-----------+----------+-------------+------+----------+

# %%
df_employees.printSchema()
# Out:
# root
#  |-- employee_id: string (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- department_id: string (nullable = true)
#  |-- salary: string (nullable = true)
#  |-- hire_date: string (nullable = true)

# %%
df_employees_inferschema.printSchema()
# Out:
# root
#  |-- employee_id: integer (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- department_id: integer (nullable = true)
#  |-- salary: integer (nullable = true)
#  |-- hire_date: date (nullable = true)

# %%
# 4. Read sales.csv
df_sales = spark.read.options(header=True,inferSchema=True).csv("datasets/sales.csv")
df_sales.show()
# Out:
# +-------+-----------+--------+------+----------+
# |sale_id|employee_id| product|amount| sale_date|
# +-------+-----------+--------+------+----------+
# |    100|          1|  Laptop|  2500|2025-01-10|
# |    101|          2|   Mouse|    80|2025-01-12|
# |    102|          1|Keyboard|   120|2025-01-14|
# |    103|          4| Monitor|   900|2025-02-01|
# |    104|          5|  Laptop|  2400|2025-02-04|
# |    105|          2|Keyboard|   150|2025-02-10|
# |    106|          7|   Mouse|    90|2025-02-15|
# |    107|          8| Monitor|   850|2025-03-01|
# +-------+-----------+--------+------+----------+

# %%
# 5. Read multiple CSV files together
df_mult_csv = (
    spark.read
    .options(header=True, inferSchema=True)
    .format("csv")
    .csv(["datasets/sales.csv", "datasets/products.csv"])
)
df_mult_csv.show()
# Out:
# +-------+-----------+-----------+------+----------+
# |sale_id|employee_id|    product|amount| sale_date|
# +-------+-----------+-----------+------+----------+
# |    100|          1|     Laptop|  2500|2025-01-10|
# |    101|          2|      Mouse|    80|2025-01-12|
# |    102|          1|   Keyboard|   120|2025-01-14|
# |    103|          4|    Monitor|   900|2025-02-01|
# |    104|          5|     Laptop|  2400|2025-02-04|
# |    105|          2|   Keyboard|   150|2025-02-10|
# |    106|          7|      Mouse|    90|2025-02-15|
# |    107|          8|    Monitor|   850|2025-03-01|
# |      1|     Laptop|Electronics|  2500|      NULL|
# |      2|      Mouse|Accessories|    80|      NULL|
# |      3|   Keyboard|Accessories|   120|      NULL|
# |      4|    Monitor|Electronics|   900|      NULL|
# +-------+-----------+-----------+------+----------+
# 26/05/27 13:20:18 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 4, schema size: 5
# CSV file: file:///app/datasets/products.csv

# %%
# 6. Create DataFrame manually
df_created = spark.createDataFrame([{"name":"lucas", "age":29, "dept":"data", "hire_date":"2023-01-01"},
                                    {"name":"mateus", "age":27, "dept":"comercial", "hire_date":"2023-01-01"},
                                    {"name":"pedro", "age":23, "dept":"health", "hire_date":"2023-01-01"}])
df_created.show()
# Out:
# +---+---------+----------+------+
# |age|     dept| hire_date|  name|
# +---+---------+----------+------+
# | 29|     data|2023-01-01| lucas|
# | 27|comercial|2023-01-01|mateus|
# | 23|   health|2023-01-01| pedro|
# +---+---------+----------+------+

# %%
data = [
    ("lucas", 29, "data", "2023-01-01"),
    ("mateus", 27, "comercial", "2023-01-01"),
    ("pedro", 23, "health", "2023-01-01")
]

columns = ["name", "age", "dept", "hire_date"]

df = spark.createDataFrame(data, columns)

df.show()
# Out:
# +------+---+---------+----------+
# |  name|age|     dept| hire_date|
# +------+---+---------+----------+
# | lucas| 29|     data|2023-01-01|
# |mateus| 27|comercial|2023-01-01|
# | pedro| 23|   health|2023-01-01|
# +------+---+---------+----------+

# %%
# 8. Display first 5 rows
df_sales.show(5)
# Out:
# +-------+-----------+--------+------+----------+
# |sale_id|employee_id| product|amount| sale_date|
# +-------+-----------+--------+------+----------+
# |    100|          1|  Laptop|  2500|2025-01-10|
# |    101|          2|   Mouse|    80|2025-01-12|
# |    102|          1|Keyboard|   120|2025-01-14|
# |    103|          4| Monitor|   900|2025-02-01|
# |    104|          5|  Laptop|  2400|2025-02-04|
# +-------+-----------+--------+------+----------+
# only showing top 5 rows

# %%
# 9. Print schema
df_sales.printSchema()
# Out:
# root
#  |-- sale_id: integer (nullable = true)
#  |-- employee_id: integer (nullable = true)
#  |-- product: string (nullable = true)
#  |-- amount: integer (nullable = true)
#  |-- sale_date: date (nullable = true)

# %%
# 10. Show distinct departments
df_departments = spark.read.options(header=True,inferSchema=True).csv("datasets/departments.csv")
df_departments.select("department_name").distinct().show()
# Out:
# +---------------+
# |department_name|
# +---------------+
# |           Data|
# |             HR|
# |        Finance|
# +---------------+

# %% [markdown]
# ## Module 2

# %% [markdown]
# 1. Select first_name column
# 2. Select first_name and salary
# 3. Filter salary > 5000
# 4. Filter salary between 5000 and 7000
# 5. Filter department_id = 10
# 6. Filter using AND condition
# 7. Filter using OR condition
# 8. Filter using isin()
# 9. Sort salaries ascending
# 10. Sort salaries descending

# %%
# 1. Select first_name column
df_employees.select("first_name").show()
# Out:
# +----------+
# |first_name|
# +----------+
# |     Lucas|
# |       Ana|
# |    Carlos|
# |     Maria|
# |      Joao|
# |  Fernanda|
# |     Pedro|
# |     Julia|
# +----------+

# %%
# 2. Select first_name and salary
df_employees.select(["first_name", "salary"]).show()
# Out:
# +----------+------+
# |first_name|salary|
# +----------+------+
# |     Lucas|  5000|
# |       Ana|  7000|
# |    Carlos|  4500|
# |     Maria|  8000|
# |      Joao|  6200|
# |  Fernanda|  7200|
# |     Pedro|  5100|
# |     Julia|  6800|
# +----------+------+

# %%
# 3. Filter salary > 5000
df_employees.filter(df_employees.salary > 5000).show()
# Out:
# +-----------+----------+-------------+------+----------+
# |employee_id|first_name|department_id|salary| hire_date|
# +-----------+----------+-------------+------+----------+
# |          2|       Ana|           20|  7000|2021-03-15|
# |          4|     Maria|           30|  8000|2020-08-20|
# |          5|      Joao|           20|  6200|2022-11-11|
# |          6|  Fernanda|           30|  7200|2019-07-07|
# |          7|     Pedro|           10|  5100|2024-01-05|
# |          8|     Julia|           20|  6800|2021-12-12|
# +-----------+----------+-------------+------+----------+

# %%
#or
df_employees.filter("salary > 5000").show()
# Out:
# +-----------+----------+-------------+------+----------+
# |employee_id|first_name|department_id|salary| hire_date|
# +-----------+----------+-------------+------+----------+
# |          2|       Ana|           20|  7000|2021-03-15|
# |          4|     Maria|           30|  8000|2020-08-20|
# |          5|      Joao|           20|  6200|2022-11-11|
# |          6|  Fernanda|           30|  7200|2019-07-07|
# |          7|     Pedro|           10|  5100|2024-01-05|
# |          8|     Julia|           20|  6800|2021-12-12|
# +-----------+----------+-------------+------+----------+

# %%
# 4. Filter salary between 5000 and 7000
df_employees.filter((df_employees.salary <= 7000) & (df_employees.salary >= 5000)).show()
# Out:
# +-----------+----------+-------------+------+----------+
# |employee_id|first_name|department_id|salary| hire_date|
# +-----------+----------+-------------+------+----------+
# |          1|     Lucas|           10|  5000|2022-01-10|
# |          2|       Ana|           20|  7000|2021-03-15|
# |          5|      Joao|           20|  6200|2022-11-11|
# |          7|     Pedro|           10|  5100|2024-01-05|
# |          8|     Julia|           20|  6800|2021-12-12|
# +-----------+----------+-------------+------+----------+

# %%
# 5. Filter department_id = 10
df_employees.filter(df_employees.department_id == 10).show()
# Out:
# +-----------+----------+-------------+------+----------+
# |employee_id|first_name|department_id|salary| hire_date|
# +-----------+----------+-------------+------+----------+
# |          1|     Lucas|           10|  5000|2022-01-10|
# |          3|    Carlos|           10|  4500|2023-06-01|
# |          7|     Pedro|           10|  5100|2024-01-05|
# +-----------+----------+-------------+------+----------+

# %%
# 6. Filter using AND condition
df_employees.filter("(salary < 7000) AND (salary > 5000)").show()
# Out:
# +-----------+----------+-------------+------+----------+
# |employee_id|first_name|department_id|salary| hire_date|
# +-----------+----------+-------------+------+----------+
# |          5|      Joao|           20|  6200|2022-11-11|
# |          7|     Pedro|           10|  5100|2024-01-05|
# |          8|     Julia|           20|  6800|2021-12-12|
# +-----------+----------+-------------+------+----------+

# %%
# 7. Filter using OR condition
df_employees.filter("(salary >5000) OR (department_id ==10)").show()
# Out:
# +-----------+----------+-------------+------+----------+
# |employee_id|first_name|department_id|salary| hire_date|
# +-----------+----------+-------------+------+----------+
# |          1|     Lucas|           10|  5000|2022-01-10|
# |          2|       Ana|           20|  7000|2021-03-15|
# |          3|    Carlos|           10|  4500|2023-06-01|
# |          4|     Maria|           30|  8000|2020-08-20|
# |          5|      Joao|           20|  6200|2022-11-11|
# |          6|  Fernanda|           30|  7200|2019-07-07|
# |          7|     Pedro|           10|  5100|2024-01-05|
# |          8|     Julia|           20|  6800|2021-12-12|
# +-----------+----------+-------------+------+----------+

# %%
# 8. Filter using isin()
df_employees.filter(df_employees.department_id.isin([10, 20])).show()
# Out:
# +-----------+----------+-------------+------+----------+
# |employee_id|first_name|department_id|salary| hire_date|
# +-----------+----------+-------------+------+----------+
# |          1|     Lucas|           10|  5000|2022-01-10|
# |          2|       Ana|           20|  7000|2021-03-15|
# |          3|    Carlos|           10|  4500|2023-06-01|
# |          5|      Joao|           20|  6200|2022-11-11|
# |          7|     Pedro|           10|  5100|2024-01-05|
# |          8|     Julia|           20|  6800|2021-12-12|
# +-----------+----------+-------------+------+----------+

# %%
df_employees.filter("department_id IN (10,20)").show()
# Out:
# +-----------+----------+-------------+------+----------+
# |employee_id|first_name|department_id|salary| hire_date|
# +-----------+----------+-------------+------+----------+
# |          1|     Lucas|           10|  5000|2022-01-10|
# |          2|       Ana|           20|  7000|2021-03-15|
# |          3|    Carlos|           10|  4500|2023-06-01|
# |          5|      Joao|           20|  6200|2022-11-11|
# |          7|     Pedro|           10|  5100|2024-01-05|
# |          8|     Julia|           20|  6800|2021-12-12|
# +-----------+----------+-------------+------+----------+

# %%
# 9. Sort salaries ascending
df_employees.sort(df_employees.salary.asc()).show()
# Out:
# +-----------+----------+-------------+------+----------+
# |employee_id|first_name|department_id|salary| hire_date|
# +-----------+----------+-------------+------+----------+
# |          3|    Carlos|           10|  4500|2023-06-01|
# |          1|     Lucas|           10|  5000|2022-01-10|
# |          7|     Pedro|           10|  5100|2024-01-05|
# |          5|      Joao|           20|  6200|2022-11-11|
# |          8|     Julia|           20|  6800|2021-12-12|
# |          2|       Ana|           20|  7000|2021-03-15|
# |          6|  Fernanda|           30|  7200|2019-07-07|
# |          4|     Maria|           30|  8000|2020-08-20|
# +-----------+----------+-------------+------+----------+

# %%
# 10. Sort salaries descending
df_employees.sort(df_employees.salary.desc()).show()
# Out:
# +-----------+----------+-------------+------+----------+
# |employee_id|first_name|department_id|salary| hire_date|
# +-----------+----------+-------------+------+----------+
# |          4|     Maria|           30|  8000|2020-08-20|
# |          6|  Fernanda|           30|  7200|2019-07-07|
# |          2|       Ana|           20|  7000|2021-03-15|
# |          8|     Julia|           20|  6800|2021-12-12|
# |          5|      Joao|           20|  6200|2022-11-11|
# |          7|     Pedro|           10|  5100|2024-01-05|
# |          1|     Lucas|           10|  5000|2022-01-10|
# |          3|    Carlos|           10|  4500|2023-06-01|
# +-----------+----------+-------------+------+----------+

# %% [markdown]
# ## Module 3

# %% [markdown]
# 1. Create annual_salary column
# 2. Create bonus column
# 3. Convert names to uppercase
# 4. Convert names to lowercase
# 5. Concatenate first_name with department_id
# 6. Extract year from hire_date
# 7. Extract month from hire_date
# 8. Create salary_level using when()
# 9. Cast salary to string
# 10. Drop a column

# %%
# 1. Create annual_salary column
from pyspark.sql.functions import col
df_employees = spark.read.options(header=True, inferSchema=True).csv("datasets/employees.csv")

df_employees = df_employees.withColumn(colName="annual_salary", col=col("salary")*12)
df_employees.show()
# Out:
# +-----------+----------+-------------+------+----------+-------------+
# |employee_id|first_name|department_id|salary| hire_date|annual_salary|
# +-----------+----------+-------------+------+----------+-------------+
# |          1|     Lucas|           10|  5000|2022-01-10|        60000|
# |          2|       Ana|           20|  7000|2021-03-15|        84000|
# |          3|    Carlos|           10|  4500|2023-06-01|        54000|
# |          4|     Maria|           30|  8000|2020-08-20|        96000|
# |          5|      Joao|           20|  6200|2022-11-11|        74400|
# |          6|  Fernanda|           30|  7200|2019-07-07|        86400|
# |          7|     Pedro|           10|  5100|2024-01-05|        61200|
# |          8|     Julia|           20|  6800|2021-12-12|        81600|
# +-----------+----------+-------------+------+----------+-------------+

# %%
# 2. Create bonus column
df_employees = df_employees.withColumn("bonus", col('salary')*0.10)
df_employees.show()
# Out:
# +-----------+----------+-------------+------+----------+-------------+-----+
# |employee_id|first_name|department_id|salary| hire_date|annual_salary|bonus|
# +-----------+----------+-------------+------+----------+-------------+-----+
# |          1|     Lucas|           10|  5000|2022-01-10|        60000|500.0|
# |          2|       Ana|           20|  7000|2021-03-15|        84000|700.0|
# |          3|    Carlos|           10|  4500|2023-06-01|        54000|450.0|
# |          4|     Maria|           30|  8000|2020-08-20|        96000|800.0|
# |          5|      Joao|           20|  6200|2022-11-11|        74400|620.0|
# |          6|  Fernanda|           30|  7200|2019-07-07|        86400|720.0|
# |          7|     Pedro|           10|  5100|2024-01-05|        61200|510.0|
# |          8|     Julia|           20|  6800|2021-12-12|        81600|680.0|
# +-----------+----------+-------------+------+----------+-------------+-----+

# %%
# 3. Convert names to uppercase
from pyspark.sql.functions import upper, lower

df_employees.withColumn("first_name", upper(col("first_name"))).show()
# Out:
# +-----------+----------+-------------+------+----------+-------------+-----+
# |employee_id|first_name|department_id|salary| hire_date|annual_salary|bonus|
# +-----------+----------+-------------+------+----------+-------------+-----+
# |          1|     LUCAS|           10|  5000|2022-01-10|        60000|500.0|
# |          2|       ANA|           20|  7000|2021-03-15|        84000|700.0|
# |          3|    CARLOS|           10|  4500|2023-06-01|        54000|450.0|
# |          4|     MARIA|           30|  8000|2020-08-20|        96000|800.0|
# |          5|      JOAO|           20|  6200|2022-11-11|        74400|620.0|
# |          6|  FERNANDA|           30|  7200|2019-07-07|        86400|720.0|
# |          7|     PEDRO|           10|  5100|2024-01-05|        61200|510.0|
# |          8|     JULIA|           20|  6800|2021-12-12|        81600|680.0|
# +-----------+----------+-------------+------+----------+-------------+-----+

# %%
df_employees.show()
# Out:
# +-----------+----------+-------------+------+----------+-------------+-----+
# |employee_id|first_name|department_id|salary| hire_date|annual_salary|bonus|
# +-----------+----------+-------------+------+----------+-------------+-----+
# |          1|     Lucas|           10|  5000|2022-01-10|        60000|500.0|
# |          2|       Ana|           20|  7000|2021-03-15|        84000|700.0|
# |          3|    Carlos|           10|  4500|2023-06-01|        54000|450.0|
# |          4|     Maria|           30|  8000|2020-08-20|        96000|800.0|
# |          5|      Joao|           20|  6200|2022-11-11|        74400|620.0|
# |          6|  Fernanda|           30|  7200|2019-07-07|        86400|720.0|
# |          7|     Pedro|           10|  5100|2024-01-05|        61200|510.0|
# |          8|     Julia|           20|  6800|2021-12-12|        81600|680.0|
# +-----------+----------+-------------+------+----------+-------------+-----+

# %%
# 4. Convert names to lowercase
df_employees.withColumn("first_name", lower(col("first_name"))).show()
# Out:
# +-----------+----------+-------------+------+----------+-------------+-----+
# |employee_id|first_name|department_id|salary| hire_date|annual_salary|bonus|
# +-----------+----------+-------------+------+----------+-------------+-----+
# |          1|     lucas|           10|  5000|2022-01-10|        60000|500.0|
# |          2|       ana|           20|  7000|2021-03-15|        84000|700.0|
# |          3|    carlos|           10|  4500|2023-06-01|        54000|450.0|
# |          4|     maria|           30|  8000|2020-08-20|        96000|800.0|
# |          5|      joao|           20|  6200|2022-11-11|        74400|620.0|
# |          6|  fernanda|           30|  7200|2019-07-07|        86400|720.0|
# |          7|     pedro|           10|  5100|2024-01-05|        61200|510.0|
# |          8|     julia|           20|  6800|2021-12-12|        81600|680.0|
# +-----------+----------+-------------+------+----------+-------------+-----+

# %%
# 5. Concatenate first_name with department_id
from pyspark.sql.functions import concat, lit

df_employees.withColumn("name_department_concat", concat(col("first_name"), lit("_"), col("department_id"))).show()
# Out:
# +-----------+----------+-------------+------+----------+-------------+-----+----------------------+
# |employee_id|first_name|department_id|salary| hire_date|annual_salary|bonus|name_department_concat|
# +-----------+----------+-------------+------+----------+-------------+-----+----------------------+
# |          1|     Lucas|           10|  5000|2022-01-10|        60000|500.0|              Lucas_10|
# |          2|       Ana|           20|  7000|2021-03-15|        84000|700.0|                Ana_20|
# |          3|    Carlos|           10|  4500|2023-06-01|        54000|450.0|             Carlos_10|
# |          4|     Maria|           30|  8000|2020-08-20|        96000|800.0|              Maria_30|
# |          5|      Joao|           20|  6200|2022-11-11|        74400|620.0|               Joao_20|
# |          6|  Fernanda|           30|  7200|2019-07-07|        86400|720.0|           Fernanda_30|
# |          7|     Pedro|           10|  5100|2024-01-05|        61200|510.0|              Pedro_10|
# |          8|     Julia|           20|  6800|2021-12-12|        81600|680.0|              Julia_20|
# +-----------+----------+-------------+------+----------+-------------+-----+----------------------+

# %%
# 6. Extract year from hire_date
from pyspark.sql.functions import year

df_employees.withColumn("year", year(col("hire_date"))).show()
# Out:
# +-----------+----------+-------------+------+----------+-------------+-----+----+
# |employee_id|first_name|department_id|salary| hire_date|annual_salary|bonus|year|
# +-----------+----------+-------------+------+----------+-------------+-----+----+
# |          1|     Lucas|           10|  5000|2022-01-10|        60000|500.0|2022|
# |          2|       Ana|           20|  7000|2021-03-15|        84000|700.0|2021|
# |          3|    Carlos|           10|  4500|2023-06-01|        54000|450.0|2023|
# |          4|     Maria|           30|  8000|2020-08-20|        96000|800.0|2020|
# |          5|      Joao|           20|  6200|2022-11-11|        74400|620.0|2022|
# |          6|  Fernanda|           30|  7200|2019-07-07|        86400|720.0|2019|
# |          7|     Pedro|           10|  5100|2024-01-05|        61200|510.0|2024|
# |          8|     Julia|           20|  6800|2021-12-12|        81600|680.0|2021|
# +-----------+----------+-------------+------+----------+-------------+-----+----+

# %%
# 7. Extract month from hire_date
from pyspark.sql.functions import month

df_employees.select("*", month(col("hire_date")).alias("month")).show()
# Out:
# +-----------+----------+-------------+------+----------+-------------+-----+-----+
# |employee_id|first_name|department_id|salary| hire_date|annual_salary|bonus|month|
# +-----------+----------+-------------+------+----------+-------------+-----+-----+
# |          1|     Lucas|           10|  5000|2022-01-10|        60000|500.0|    1|
# |          2|       Ana|           20|  7000|2021-03-15|        84000|700.0|    3|
# |          3|    Carlos|           10|  4500|2023-06-01|        54000|450.0|    6|
# |          4|     Maria|           30|  8000|2020-08-20|        96000|800.0|    8|
# |          5|      Joao|           20|  6200|2022-11-11|        74400|620.0|   11|
# |          6|  Fernanda|           30|  7200|2019-07-07|        86400|720.0|    7|
# |          7|     Pedro|           10|  5100|2024-01-05|        61200|510.0|    1|
# |          8|     Julia|           20|  6800|2021-12-12|        81600|680.0|   12|
# +-----------+----------+-------------+------+----------+-------------+-----+-----+

# %%
df_employees.select("*", year(col("hire_date")).alias("year"), month(col("hire_date")).alias("month")).show()
# Out:
# +-----------+----------+-------------+------+----------+-------------+-----+----+-----+
# |employee_id|first_name|department_id|salary| hire_date|annual_salary|bonus|year|month|
# +-----------+----------+-------------+------+----------+-------------+-----+----+-----+
# |          1|     Lucas|           10|  5000|2022-01-10|        60000|500.0|2022|    1|
# |          2|       Ana|           20|  7000|2021-03-15|        84000|700.0|2021|    3|
# |          3|    Carlos|           10|  4500|2023-06-01|        54000|450.0|2023|    6|
# |          4|     Maria|           30|  8000|2020-08-20|        96000|800.0|2020|    8|
# |          5|      Joao|           20|  6200|2022-11-11|        74400|620.0|2022|   11|
# |          6|  Fernanda|           30|  7200|2019-07-07|        86400|720.0|2019|    7|
# |          7|     Pedro|           10|  5100|2024-01-05|        61200|510.0|2024|    1|
# |          8|     Julia|           20|  6800|2021-12-12|        81600|680.0|2021|   12|
# +-----------+----------+-------------+------+----------+-------------+-----+----+-----+

# %%
# 8. Create salary_level using when()
from pyspark.sql.functions import when

df_employees.withColumn(
    "salary_level",
    when(col("annual_salary") > 80000, "high")
    .when(col("annual_salary") > 61000, "medium")
    .otherwise("low")
).show()
# Out:
# +-----------+----------+-------------+------+----------+-------------+-----+------------+
# |employee_id|first_name|department_id|salary| hire_date|annual_salary|bonus|salary_level|
# +-----------+----------+-------------+------+----------+-------------+-----+------------+
# |          1|     Lucas|           10|  5000|2022-01-10|        60000|500.0|         low|
# |          2|       Ana|           20|  7000|2021-03-15|        84000|700.0|        high|
# |          3|    Carlos|           10|  4500|2023-06-01|        54000|450.0|         low|
# |          4|     Maria|           30|  8000|2020-08-20|        96000|800.0|        high|
# |          5|      Joao|           20|  6200|2022-11-11|        74400|620.0|      medium|
# |          6|  Fernanda|           30|  7200|2019-07-07|        86400|720.0|        high|
# |          7|     Pedro|           10|  5100|2024-01-05|        61200|510.0|      medium|
# |          8|     Julia|           20|  6800|2021-12-12|        81600|680.0|        high|
# +-----------+----------+-------------+------+----------+-------------+-----+------------+

# %%
df_employees.select("*", when(col("annual_salary") > 80000, "high")
    .when(col("annual_salary") > 61000, "medium")
    .otherwise("low").alias("level")).show()
# Out:
# +-----------+----------+-------------+------+----------+-------------+-----+------+
# |employee_id|first_name|department_id|salary| hire_date|annual_salary|bonus| level|
# +-----------+----------+-------------+------+----------+-------------+-----+------+
# |          1|     Lucas|           10|  5000|2022-01-10|        60000|500.0|   low|
# |          2|       Ana|           20|  7000|2021-03-15|        84000|700.0|  high|
# |          3|    Carlos|           10|  4500|2023-06-01|        54000|450.0|   low|
# |          4|     Maria|           30|  8000|2020-08-20|        96000|800.0|  high|
# |          5|      Joao|           20|  6200|2022-11-11|        74400|620.0|medium|
# |          6|  Fernanda|           30|  7200|2019-07-07|        86400|720.0|  high|
# |          7|     Pedro|           10|  5100|2024-01-05|        61200|510.0|medium|
# |          8|     Julia|           20|  6800|2021-12-12|        81600|680.0|  high|
# +-----------+----------+-------------+------+----------+-------------+-----+------+

# %%
# 9. Cast salary to string

df_employees.select("*", col("salary").cast("string").alias("string_salary")).printSchema()
# Out:
# root
#  |-- employee_id: integer (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- department_id: integer (nullable = true)
#  |-- salary: integer (nullable = true)
#  |-- hire_date: date (nullable = true)
#  |-- annual_salary: integer (nullable = true)
#  |-- bonus: double (nullable = true)
#  |-- string_salary: string (nullable = true)

# %%
# 10. Drop a column

df_employees.drop("bonus").show()
# Out:
# +-----------+----------+-------------+------+----------+-------------+
# |employee_id|first_name|department_id|salary| hire_date|annual_salary|
# +-----------+----------+-------------+------+----------+-------------+
# |          1|     Lucas|           10|  5000|2022-01-10|        60000|
# |          2|       Ana|           20|  7000|2021-03-15|        84000|
# |          3|    Carlos|           10|  4500|2023-06-01|        54000|
# |          4|     Maria|           30|  8000|2020-08-20|        96000|
# |          5|      Joao|           20|  6200|2022-11-11|        74400|
# |          6|  Fernanda|           30|  7200|2019-07-07|        86400|
# |          7|     Pedro|           10|  5100|2024-01-05|        61200|
# |          8|     Julia|           20|  6800|2021-12-12|        81600|
# +-----------+----------+-------------+------+----------+-------------+

# %%
df_employees.show()
# Out:
# +-----------+----------+-------------+------+----------+-------------+-----+
# |employee_id|first_name|department_id|salary| hire_date|annual_salary|bonus|
# +-----------+----------+-------------+------+----------+-------------+-----+
# |          1|     Lucas|           10|  5000|2022-01-10|        60000|500.0|
# |          2|       Ana|           20|  7000|2021-03-15|        84000|700.0|
# |          3|    Carlos|           10|  4500|2023-06-01|        54000|450.0|
# |          4|     Maria|           30|  8000|2020-08-20|        96000|800.0|
# |          5|      Joao|           20|  6200|2022-11-11|        74400|620.0|
# |          6|  Fernanda|           30|  7200|2019-07-07|        86400|720.0|
# |          7|     Pedro|           10|  5100|2024-01-05|        61200|510.0|
# |          8|     Julia|           20|  6800|2021-12-12|        81600|680.0|
# +-----------+----------+-------------+------+----------+-------------+-----+

# %% [markdown]
# ## Module 4

# %% [markdown]
# 1. Average salary by department
# 2. Sum salary by department
# 3. Count employees by department
# 4. Maximum salary
# 5. Minimum salary
# 6. Count distinct departments
# 7. Group by department and hire year
# 8. Order aggregation results
# 9. Filter grouped results
# 10. Multiple aggregations in one query

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import avg, col, max, min, year, round, sum, count_distinct, count

spark = (
    SparkSession.builder
    .appName("training")
    .getOrCreate()
)
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://e02226551e85:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>training</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_employees = spark.read.options(header=True, inferSchema=True).csv("datasets/employees.csv")

# %%
# 1. Average salary by department
df_employees.groupBy(col("department_id")) \
    .agg(
        round(avg(col("salary")),2).alias("salary_avg")
    ) \
    .orderBy(col("department_id")) \
    .show()
# Out:
# +-------------+----------+
# |department_id|salary_avg|
# +-------------+----------+
# |           10|   4866.67|
# |           20|   6666.67|
# |           30|    7600.0|
# +-------------+----------+

# %%
# 2. Sum salary by department
df_employees.groupBy("department_id") \
    .agg(
        sum("salary").alias("total_salary")
    ) \
    .orderBy("department_id") \
    .show()
# Out:
# +-------------+------------+
# |department_id|total_salary|
# +-------------+------------+
# |           10|       14600|
# |           20|       20000|
# |           30|       15200|
# +-------------+------------+

# %%
# 3. Count employees by department
df_employees.groupBy("department_id") \
    .agg(
        count("employee_id").alias("total_employees")) \
    .orderBy("department_id") \
    .show()
# Out:
# +-------------+---------------+
# |department_id|total_employees|
# +-------------+---------------+
# |           10|              3|
# |           20|              3|
# |           30|              2|
# +-------------+---------------+

# %%
# 4. Maximum salary

df_employees.agg(max("salary").alias("max_salary")).show()
# Out:
# +----------+
# |max_salary|
# +----------+
# |      8000|
# +----------+

# %%
# 5. Minimum salary
df_employees.agg(min("salary").alias("min_salary")).show()
# Out:
# +----------+
# |min_salary|
# +----------+
# |      4500|
# +----------+

# %%
# 6. Count distinct departments
df_employees.agg(count_distinct("department_id").alias("total_departments")).show()
# Out:
# +-----------------+
# |total_departments|
# +-----------------+
# |                3|
# +-----------------+

# %%
# 7. Group by department and hire year
df_employees.withColumn("hire_year", year(col("hire_date"))) \
    .groupBy("department_id", "hire_year") \
        .agg(
            sum("salary").alias("total_salary")
            ) \
        .orderBy("hire_year") \
        .show()
# Out:
# +-------------+---------+------------+
# |department_id|hire_year|total_salary|
# +-------------+---------+------------+
# |           30|     2019|        7200|
# |           30|     2020|        8000|
# |           20|     2021|       13800|
# |           10|     2022|        5000|
# |           20|     2022|        6200|
# |           10|     2023|        4500|
# |           10|     2024|        5100|
# +-------------+---------+------------+

# %%
# 8. Order aggregation results
df_employees.groupBy("department_id") \
    .agg(
        sum("salary").alias("total_salary")
    ) \
    .orderBy(col("total_salary").desc()) \
    .show()
# Out:
# +-------------+------------+
# |department_id|total_salary|
# +-------------+------------+
# |           20|       20000|
# |           30|       15200|
# |           10|       14600|
# +-------------+------------+

# %%
# 9. Filter grouped results
df_employees.groupBy("department_id") \
    .agg(
        sum("salary").alias("total_salary")
    ) \
    .filter(col("total_salary")>15000) \
    .orderBy(col("total_salary").desc()) \
    .show()
# Out:
# +-------------+------------+
# |department_id|total_salary|
# +-------------+------------+
# |           20|       20000|
# |           30|       15200|
# +-------------+------------+

# %%
# 10. Multiple aggregations in one query
df_employees.groupBy("department_id") \
    .agg(
        round(avg("salary"),2).alias("salary_avg"),
        sum("salary").alias("total_salary"),
        count("*").alias("total_employees")
        ) \
    .orderBy("department_id") \
    .show()
# Out:
# +-------------+----------+------------+---------------+
# |department_id|salary_avg|total_salary|total_employees|
# +-------------+----------+------------+---------------+
# |           10|   4866.67|       14600|              3|
# |           20|   6666.67|       20000|              3|
# |           30|    7600.0|       15200|              2|
# +-------------+----------+------------+---------------+

# %% [markdown]
# ## Module 5

# %% [markdown]
# 1. Inner join employees and departments
# 2. Left join employees and departments
# 3. Right join employees and departments
# 4. Full join employees and departments
# 5. Anti join
# 6. Semi join
# 7. Join sales and employees
# 8. Join using multiple conditions
# 9. Remove duplicates after join
# 10. Find employees without sales

# %%
# 1. Inner join employees and departments
df_employees = spark.read.options(header=True, inferSchema=True).csv("datasets/employees.csv")
df_departments = spark.read.options(header=True, inferSchema=True).csv("datasets/departments.csv")

df_employees.join(df_departments, on="department_id").show()
# Out:
# +-------------+-----------+----------+------+----------+---------------+
# |department_id|employee_id|first_name|salary| hire_date|department_name|
# +-------------+-----------+----------+------+----------+---------------+
# |           10|          1|     Lucas|  5000|2022-01-10|           Data|
# |           20|          2|       Ana|  7000|2021-03-15|        Finance|
# |           10|          3|    Carlos|  4500|2023-06-01|           Data|
# |           30|          4|     Maria|  8000|2020-08-20|             HR|
# |           20|          5|      Joao|  6200|2022-11-11|        Finance|
# |           30|          6|  Fernanda|  7200|2019-07-07|             HR|
# |           10|          7|     Pedro|  5100|2024-01-05|           Data|
# |           20|          8|     Julia|  6800|2021-12-12|        Finance|
# +-------------+-----------+----------+------+----------+---------------+

# %%
# 2. Left join employees and departments
df_employees.join(df_departments, on="department_id", how="left").show()
# Out:
# +-------------+-----------+----------+------+----------+---------------+
# |department_id|employee_id|first_name|salary| hire_date|department_name|
# +-------------+-----------+----------+------+----------+---------------+
# |           10|          1|     Lucas|  5000|2022-01-10|           Data|
# |           20|          2|       Ana|  7000|2021-03-15|        Finance|
# |           10|          3|    Carlos|  4500|2023-06-01|           Data|
# |           30|          4|     Maria|  8000|2020-08-20|             HR|
# |           20|          5|      Joao|  6200|2022-11-11|        Finance|
# |           30|          6|  Fernanda|  7200|2019-07-07|             HR|
# |           10|          7|     Pedro|  5100|2024-01-05|           Data|
# |           20|          8|     Julia|  6800|2021-12-12|        Finance|
# +-------------+-----------+----------+------+----------+---------------+

# %%
# 3. Right join employees and departments
df_employees.join(df_departments, on="department_id", how="right").show()
# Out:
# +-------------+-----------+----------+------+----------+---------------+
# |department_id|employee_id|first_name|salary| hire_date|department_name|
# +-------------+-----------+----------+------+----------+---------------+
# |           10|          7|     Pedro|  5100|2024-01-05|           Data|
# |           10|          3|    Carlos|  4500|2023-06-01|           Data|
# |           10|          1|     Lucas|  5000|2022-01-10|           Data|
# |           20|          8|     Julia|  6800|2021-12-12|        Finance|
# |           20|          5|      Joao|  6200|2022-11-11|        Finance|
# |           20|          2|       Ana|  7000|2021-03-15|        Finance|
# |           30|          6|  Fernanda|  7200|2019-07-07|             HR|
# |           30|          4|     Maria|  8000|2020-08-20|             HR|
# +-------------+-----------+----------+------+----------+---------------+

# %%
# 4. Full join employees and departments
df_employees.join(df_departments, on="department_id", how="full").show()
# Out:
# +-------------+-----------+----------+------+----------+---------------+
# |department_id|employee_id|first_name|salary| hire_date|department_name|
# +-------------+-----------+----------+------+----------+---------------+
# |           10|          1|     Lucas|  5000|2022-01-10|           Data|
# |           10|          3|    Carlos|  4500|2023-06-01|           Data|
# |           10|          7|     Pedro|  5100|2024-01-05|           Data|
# |           20|          2|       Ana|  7000|2021-03-15|        Finance|
# |           20|          5|      Joao|  6200|2022-11-11|        Finance|
# |           20|          8|     Julia|  6800|2021-12-12|        Finance|
# |           30|          4|     Maria|  8000|2020-08-20|             HR|
# |           30|          6|  Fernanda|  7200|2019-07-07|             HR|
# +-------------+-----------+----------+------+----------+---------------+

# %%
# 5. Anti join
df_employees.join(df_departments, on="department_id", how="anti").show()
# Out:
# +-------------+-----------+----------+------+---------+
# |department_id|employee_id|first_name|salary|hire_date|
# +-------------+-----------+----------+------+---------+
# +-------------+-----------+----------+------+---------+

# %%
# 6. Semi join
df_employees.join(df_departments, on="department_id", how="semi").show()
# Out:
# +-------------+-----------+----------+------+----------+
# |department_id|employee_id|first_name|salary| hire_date|
# +-------------+-----------+----------+------+----------+
# |           10|          1|     Lucas|  5000|2022-01-10|
# |           20|          2|       Ana|  7000|2021-03-15|
# |           10|          3|    Carlos|  4500|2023-06-01|
# |           30|          4|     Maria|  8000|2020-08-20|
# |           20|          5|      Joao|  6200|2022-11-11|
# |           30|          6|  Fernanda|  7200|2019-07-07|
# |           10|          7|     Pedro|  5100|2024-01-05|
# |           20|          8|     Julia|  6800|2021-12-12|
# +-------------+-----------+----------+------+----------+

# %%
# 7. Join sales and employees
df_sales = spark.read.options(header=True, inferSchema=True).csv("datasets/sales.csv")

df_sales.join(df_employees, on="employee_id").show()
# Out:
# +-----------+-------+--------+------+----------+----------+-------------+------+----------+
# |employee_id|sale_id| product|amount| sale_date|first_name|department_id|salary| hire_date|
# +-----------+-------+--------+------+----------+----------+-------------+------+----------+
# |          1|    100|  Laptop|  2500|2025-01-10|     Lucas|           10|  5000|2022-01-10|
# |          2|    101|   Mouse|    80|2025-01-12|       Ana|           20|  7000|2021-03-15|
# |          1|    102|Keyboard|   120|2025-01-14|     Lucas|           10|  5000|2022-01-10|
# |          4|    103| Monitor|   900|2025-02-01|     Maria|           30|  8000|2020-08-20|
# |          5|    104|  Laptop|  2400|2025-02-04|      Joao|           20|  6200|2022-11-11|
# |          2|    105|Keyboard|   150|2025-02-10|       Ana|           20|  7000|2021-03-15|
# |          7|    106|   Mouse|    90|2025-02-15|     Pedro|           10|  5100|2024-01-05|
# |          8|    107| Monitor|   850|2025-03-01|     Julia|           20|  6800|2021-12-12|
# +-----------+-------+--------+------+----------+----------+-------------+------+----------+

# %%
# 8. Join using multiple conditions
df_sales.join(df_employees, on=((df_sales.employee_id==df_employees.employee_id) & (df_sales.employee_id==8))).show()
# Out:
# +-------+-----------+-------+------+----------+-----------+----------+-------------+------+----------+
# |sale_id|employee_id|product|amount| sale_date|employee_id|first_name|department_id|salary| hire_date|
# +-------+-----------+-------+------+----------+-----------+----------+-------------+------+----------+
# |    107|          8|Monitor|   850|2025-03-01|          8|     Julia|           20|  6800|2021-12-12|
# +-------+-----------+-------+------+----------+-----------+----------+-------------+------+----------+

# %%
# 9. Remove duplicates after join
df = df_sales.join(df_employees, on="employee_id", how="inner")

df_sales.groupBy("employee_id").count().show()
df.dropDuplicates().show()
# Out:
# +-----------+-----+
# |employee_id|count|
# +-----------+-----+
# |          1|    2|
# |          5|    1|
# |          4|    1|
# |          8|    1|
# |          7|    1|
# |          2|    2|
# +-----------+-----+
#
# +-----------+-------+--------+------+----------+----------+-------------+------+----------+
# |employee_id|sale_id| product|amount| sale_date|first_name|department_id|salary| hire_date|
# +-----------+-------+--------+------+----------+----------+-------------+------+----------+
# |          8|    107| Monitor|   850|2025-03-01|     Julia|           20|  6800|2021-12-12|
# |          2|    105|Keyboard|   150|2025-02-10|       Ana|           20|  7000|2021-03-15|
# |          5|    104|  Laptop|  2400|2025-02-04|      Joao|           20|  6200|2022-11-11|
# |          1|    102|Keyboard|   120|2025-01-14|     Lucas|           10|  5000|2022-01-10|
# |          2|    101|   Mouse|    80|2025-01-12|       Ana|           20|  7000|2021-03-15|
# |          4|    103| Monitor|   900|2025-02-01|     Maria|           30|  8000|2020-08-20|
# |          1|    100|  Laptop|  2500|2025-01-10|     Lucas|           10|  5000|2022-01-10|
# |          7|    106|   Mouse|    90|2025-02-15|     Pedro|           10|  5100|2024-01-05|
# +-----------+-------+--------+------+----------+----------+-------------+------+----------+

# %%
# 10. Find employees without sales
df_employees.join(df_sales, on=(df_employees.employee_id==df_sales.employee_id), how="left").filter(df_sales.employee_id.isNull()).show()
# Out:
# +-----------+----------+-------------+------+----------+-------+-----------+-------+------+---------+
# |employee_id|first_name|department_id|salary| hire_date|sale_id|employee_id|product|amount|sale_date|
# +-----------+----------+-------------+------+----------+-------+-----------+-------+------+---------+
# |          3|    Carlos|           10|  4500|2023-06-01|   NULL|       NULL|   NULL|  NULL|     NULL|
# |          6|  Fernanda|           30|  7200|2019-07-07|   NULL|       NULL|   NULL|  NULL|     NULL|
# +-----------+----------+-------------+------+----------+-------+-----------+-------+------+---------+

# %% [markdown]
# ## Module 6

# %% [markdown]
# 1. row_number()
# 2. rank()
# 3. dense_rank()
# 4. Running salary total
# 5. Moving average
# 6. lag()
# 7. lead()
# 8. Top 3 salaries by department
# 9. First employee by hire_date
# 10. Last employee by hire_date

# %%
from pyspark.sql.functions import row_number, lag, lead, col, rank, dense_rank, round
from pyspark.sql.window import Window

# %%
#1. row_number()
window = (
    Window.partitionBy(col("department_id")).orderBy(col("hire_date"))
)
df_employees.withColumn("rn", row_number().over(window)).show()
# Out:
# +-----------+----------+-------------+------+----------+---+
# |employee_id|first_name|department_id|salary| hire_date| rn|
# +-----------+----------+-------------+------+----------+---+
# |          1|     Lucas|           10|  5000|2022-01-10|  1|
# |          3|    Carlos|           10|  4500|2023-06-01|  2|
# |          7|     Pedro|           10|  5100|2024-01-05|  3|
# |          2|       Ana|           20|  7000|2021-03-15|  1|
# |          8|     Julia|           20|  6800|2021-12-12|  2|
# |          5|      Joao|           20|  6200|2022-11-11|  3|
# |          6|  Fernanda|           30|  7200|2019-07-07|  1|
# |          4|     Maria|           30|  8000|2020-08-20|  2|
# +-----------+----------+-------------+------+----------+---+

# %%
# 2. rank()

window_spec = (
    Window.partitionBy("department_id").orderBy(col("hire_date").desc())
)

df_employees.select(
    "employee_id", "salary", "department_id", "hire_date", 
    rank().over(window_spec).alias("rank")
    ) \
    .filter("rank==1") \
    .show()
# Out:
# +-----------+------+-------------+----------+----+
# |employee_id|salary|department_id| hire_date|rank|
# +-----------+------+-------------+----------+----+
# |          7|  5100|           10|2024-01-05|   1|
# |          5|  6200|           20|2022-11-11|   1|
# |          4|  8000|           30|2020-08-20|   1|
# +-----------+------+-------------+----------+----+

# %%
# 3. dense_rank()
window_spec = (
    Window.orderBy(col("department_id"))
)
df_employees.select("department_id", dense_rank().over(window_spec).alias("dense_rank")).show()

## IN A MASSIVE DATASET NOT SPECIFYING THE PARTITION CAN BE COSTING
# Out:
# +-------------+----------+
# |department_id|dense_rank|
# +-------------+----------+
# |           10|         1|
# |           10|         1|
# |           10|         1|
# |           20|         2|
# |           20|         2|
# |           20|         2|
# |           30|         3|
# |           30|         3|
# +-------------+----------+
# 26/06/02 18:45:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/06/02 18:45:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/06/02 18:45:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.

# %%
# 4. Running salary total
window_spec = (
    Window.partitionBy("department_id").orderBy("hire_date")
)

df_employees.select("department_id", sum("salary").over(window_spec).alias("total_department")).show()
# Out:
# +-------------+----------------+
# |department_id|total_department|
# +-------------+----------------+
# |           10|            5000|
# |           10|            9500|
# |           10|           14600|
# |           20|            7000|
# |           20|           13800|
# |           20|           20000|
# |           30|            7200|
# |           30|           15200|
# +-------------+----------------+

# %%
# 5. Moving average
window_spec = (
    Window.partitionBy("department_id").orderBy("hire_date")
)

df_employees.select("department_id", avg("salary").over(window_spec).alias("avg_salary")).show()
# Out:
# +-------------+-----------------+
# |department_id|       avg_salary|
# +-------------+-----------------+
# |           10|           5000.0|
# |           10|           4750.0|
# |           10|4866.666666666667|
# |           20|           7000.0|
# |           20|           6900.0|
# |           20|6666.666666666667|
# |           30|           7200.0|
# |           30|           7600.0|
# +-------------+-----------------+

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("testing").getOrCreate()
spark
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/08 13:19:47 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://e02226551e85:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>testing</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# 6. lag()
df_employees = spark.read.options(header=True, inferSchema=True).csv("datasets/employees.csv")

window_spec = (
    Window.partitionBy("department_id").orderBy("hire_date")
)


df_employees.select("department_id", "hire_date", lag("hire_date").over(window_spec).alias("lag_date")).show()
# Out:
# +-------------+----------+----------+
# |department_id| hire_date|  lag_date|
# +-------------+----------+----------+
# |           10|2022-01-10|      NULL|
# |           10|2023-06-01|2022-01-10|
# |           10|2024-01-05|2023-06-01|
# |           20|2021-03-15|      NULL|
# |           20|2021-12-12|2021-03-15|
# |           20|2022-11-11|2021-12-12|
# |           30|2019-07-07|      NULL|
# |           30|2020-08-20|2019-07-07|
# +-------------+----------+----------+

# %%
# 7. lead()
window_spec = (
    Window.partitionBy("department_id").orderBy("hire_date")
)


df_employees.select("department_id", "hire_date", lead("hire_date").over(window_spec).alias("lag_date")).show()
# Out:
# +-------------+----------+----------+
# |department_id| hire_date|  lag_date|
# +-------------+----------+----------+
# |           10|2022-01-10|2023-06-01|
# |           10|2023-06-01|2024-01-05|
# |           10|2024-01-05|      NULL|
# |           20|2021-03-15|2021-12-12|
# |           20|2021-12-12|2022-11-11|
# |           20|2022-11-11|      NULL|
# |           30|2019-07-07|2020-08-20|
# |           30|2020-08-20|      NULL|
# +-------------+----------+----------+

# %%
# 8. Top 2 salaries by department

window_spec = (
    Window.partitionBy("department_id").orderBy(col("salary").desc())
)

df_employees.select("department_id", "first_name", "salary", row_number().over(window_spec).alias("rn")).filter("rn < 3").show()
# Out:
# +-------------+----------+------+---+
# |department_id|first_name|salary| rn|
# +-------------+----------+------+---+
# |           10|     Pedro|  5100|  1|
# |           10|     Lucas|  5000|  2|
# |           20|       Ana|  7000|  1|
# |           20|     Julia|  6800|  2|
# |           30|     Maria|  8000|  1|
# |           30|  Fernanda|  7200|  2|
# +-------------+----------+------+---+

# %%
# 9. First employee by hire_date
window_spec = (
    Window.partitionBy("department_id").orderBy(col("hire_date"))
)

df_employees.select("department_id", "first_name","hire_date", "salary", row_number().over(window_spec).alias("rn")).filter("rn = 1").show()
# Out:
# +-------------+----------+----------+------+---+
# |department_id|first_name| hire_date|salary| rn|
# +-------------+----------+----------+------+---+
# |           10|     Lucas|2022-01-10|  5000|  1|
# |           20|       Ana|2021-03-15|  7000|  1|
# |           30|  Fernanda|2019-07-07|  7200|  1|
# +-------------+----------+----------+------+---+

# %%
 # 10. Last employee by hire_date
window_spec = (
    Window.partitionBy("department_id").orderBy(col("hire_date").desc())
)

df_employees.select("department_id", "first_name", "hire_date", "salary", row_number().over(window_spec).alias("rn")).filter("rn = 1").show()
# Out:
# +-------------+----------+----------+------+---+
# |department_id|first_name| hire_date|salary| rn|
# +-------------+----------+----------+------+---+
# |           10|     Pedro|2024-01-05|  5100|  1|
# |           20|      Joao|2022-11-11|  6200|  1|
# |           30|     Maria|2020-08-20|  8000|  1|
# +-------------+----------+----------+------+---+

# %% [markdown]
# ## Module 7

# %% [markdown]
# 1. Convert string to date
# 2. Extract year
# 3. Extract month
# 4. Extract day
# 5. Calculate date difference
# 6. Add days
# 7. Add months
# 8. Filter date range
# 9. Create timestamp
# 10. Work with current_date()

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, year, month, day, date_add, date_diff, current_date

spark = SparkSession.builder.appName("test").getOrCreate()
df_employees = spark.read.options(header=True, inferSchema=True).csv("datasets/employees.csv")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/10 12:39:17 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# 1. Convert string to date

data = [
    (1, "2020-01-01"),
    (2, "2022-01-01"),
    (3, "2025-01-01"),
    (4, "2026-01-01"),
    (5, "2027-01-01")
]

column_names = [
    "id", "date"
]

df = spark.createDataFrame(data, column_names)
df.select("id", col("date").cast("date").alias("date")).printSchema()
df.select("id", col("date").cast("date").alias("date")).show()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- date: date (nullable = true)
#
# +---+----------+
# | id|      date|
# +---+----------+
# |  1|2020-01-01|
# |  2|2022-01-01|
# |  3|2025-01-01|
# |  4|2026-01-01|
# |  5|2027-01-01|
# +---+----------+

# %%
# 2. Extract year
df = df.select("id", col("date").cast("date").alias("date"))
df.withColumn("year", year(col("date"))).show()
# Out:
# +---+----------+----+
# | id|      date|year|
# +---+----------+----+
# |  1|2020-01-01|2020|
# |  2|2022-01-01|2022|
# |  3|2025-01-01|2025|
# |  4|2026-01-01|2026|
# |  5|2027-01-01|2027|
# +---+----------+----+

# %%
#3. Extract month
df.withColumn("month", month(col("date"))).show()
# Out:
# +---+----------+-----+
# | id|      date|month|
# +---+----------+-----+
# |  1|2020-01-01|    1|
# |  2|2022-01-01|    1|
# |  3|2025-01-01|    1|
# |  4|2026-01-01|    1|
# |  5|2027-01-01|    1|
# +---+----------+-----+

# %%
# 4. Extract day
df.withColumn("day", day(col("date"))).show()
# Out:
# +---+----------+---+
# | id|      date|day|
# +---+----------+---+
# |  1|2020-01-01|  1|
# |  2|2022-01-01|  1|
# |  3|2025-01-01|  1|
# |  4|2026-01-01|  1|
# |  5|2027-01-01|  1|
# +---+----------+---+

# %%
# 5. Calculate date difference
from pyspark.sql.window import Window
from pyspark.sql.functions import lead, datediff, to_date, row_number, desc, dateadd

data = [
    (101, "Lucas", "2024-01-15"),
    (101, "Lucas", "2024-03-10"),
    (101, "Lucas", "2024-06-20"),
    (102, "Maria", "2024-02-01"),
    (102, "Maria", "2024-05-15"),
    (102, "Maria", "2024-09-01"),
    (103, "John", "2024-01-05"),
    (103, "John", "2024-04-18")
]

column_names = [
    "employee_id",
    "employee_name",
    "event_date"
]

df1 = spark.createDataFrame(data, column_names)

df1 = df1.withColumn(
    "event_date",
    to_date("event_date")
)

window_spec = (
    Window.partitionBy("employee_name")
          .orderBy("event_date")
)

(
    df1
    .withColumn(
        "next_event_date",
        lead("event_date").over(window_spec)
    )
    .withColumn(
        "date_diff",
        datediff("next_event_date", "event_date")
    )
    .orderBy("employee_id")
    .show()
)
# Out:
# [Stage 2:>                                                          (0 + 8) / 8]
# +-----------+-------------+----------+---------------+---------+
# |employee_id|employee_name|event_date|next_event_date|date_diff|
# +-----------+-------------+----------+---------------+---------+
# |        101|        Lucas|2024-01-15|     2024-03-10|       55|
# |        101|        Lucas|2024-03-10|     2024-06-20|      102|
# |        101|        Lucas|2024-06-20|           NULL|     NULL|
# |        102|        Maria|2024-02-01|     2024-05-15|      104|
# |        102|        Maria|2024-05-15|     2024-09-01|      109|
# |        102|        Maria|2024-09-01|           NULL|     NULL|
# |        103|         John|2024-01-05|     2024-04-18|      104|
# |        103|         John|2024-04-18|           NULL|     NULL|
# +-----------+-------------+----------+---------------+---------+

# %%
# 6. Add days

window_spec = (
    Window.partitionBy("employee_name").orderBy(col("event_date").desc())
)

df1.withColumn(
    "event_order", row_number().over(window_spec)
) \
.filter("event_order = 1") \
.withColumn("next_event", dateadd("event_date", 30)) \
.show()
# Out:
# [Stage 21:>                                                         (0 + 8) / 8]
# +-----------+-------------+----------+-----------+----------+
# |employee_id|employee_name|event_date|event_order|next_event|
# +-----------+-------------+----------+-----------+----------+
# |        103|         John|2024-04-18|          1|2024-05-18|
# |        101|        Lucas|2024-06-20|          1|2024-07-20|
# |        102|        Maria|2024-09-01|          1|2024-10-01|
# +-----------+-------------+----------+-----------+----------+

# %%
# 7. Add months

from pyspark.sql.functions import add_months

window_spec = (
    Window.partitionBy("employee_name").orderBy(col("event_date").desc())
)

df1.withColumn(
    "event_order", row_number().over(window_spec)
) \
.filter("event_order = 1") \
.withColumn("next_event", add_months("event_date", 1)) \
.show()
# Out:
# +-----------+-------------+----------+-----------+----------+
# |employee_id|employee_name|event_date|event_order|next_event|
# +-----------+-------------+----------+-----------+----------+
# |        103|         John|2024-04-18|          1|2024-05-18|
# |        101|        Lucas|2024-06-20|          1|2024-07-20|
# |        102|        Maria|2024-09-01|          1|2024-10-01|
# +-----------+-------------+----------+-----------+----------+

# %%
# 8. Filter date range

df1.select("*").filter("event_date >= '2024-02-01' and event_date <= '2024-05-15'").show()
# Out:
# +-----------+-------------+----------+
# |employee_id|employee_name|event_date|
# +-----------+-------------+----------+
# |        101|        Lucas|2024-03-10|
# |        102|        Maria|2024-02-01|
# |        102|        Maria|2024-05-15|
# |        103|         John|2024-04-18|
# +-----------+-------------+----------+

# %%
# 9. Create timestamp
from pyspark.sql.functions import to_timestamp

df1.withColumn("event_timestamp", to_timestamp("event_date")).show()
# Out:
# +-----------+-------------+----------+-------------------+
# |employee_id|employee_name|event_date|    event_timestamp|
# +-----------+-------------+----------+-------------------+
# |        101|        Lucas|2024-01-15|2024-01-15 00:00:00|
# |        101|        Lucas|2024-03-10|2024-03-10 00:00:00|
# |        101|        Lucas|2024-06-20|2024-06-20 00:00:00|
# |        102|        Maria|2024-02-01|2024-02-01 00:00:00|
# |        102|        Maria|2024-05-15|2024-05-15 00:00:00|
# |        102|        Maria|2024-09-01|2024-09-01 00:00:00|
# |        103|         John|2024-01-05|2024-01-05 00:00:00|
# |        103|         John|2024-04-18|2024-04-18 00:00:00|
# +-----------+-------------+----------+-------------------+

# %%
# 10. Work with current_date()

df1.withColumn("current_date", current_date()).withColumn("days_until_today", datediff("current_date", "event_date")).show()
# Out:
# +-----------+-------------+----------+------------+----------------+
# |employee_id|employee_name|event_date|current_date|days_until_today|
# +-----------+-------------+----------+------------+----------------+
# |        101|        Lucas|2024-01-15|  2026-06-10|             877|
# |        101|        Lucas|2024-03-10|  2026-06-10|             822|
# |        101|        Lucas|2024-06-20|  2026-06-10|             720|
# |        102|        Maria|2024-02-01|  2026-06-10|             860|
# |        102|        Maria|2024-05-15|  2026-06-10|             756|
# |        102|        Maria|2024-09-01|  2026-06-10|             647|
# |        103|         John|2024-01-05|  2026-06-10|             887|
# |        103|         John|2024-04-18|  2026-06-10|             783|
# +-----------+-------------+----------+------------+----------------+

# %% [markdown]
# ## Module 8

# %% [markdown]
# 1. Detect nulls
# 2. Drop nulls
# 3. Fill nulls
# 4. Replace null salary with average
# 5. Remove duplicates
# 6. Trim spaces
# 7. Replace values
# 8. Regex replace
# 9. Standardize text
# 10. Detect inconsistent rows

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as T

spark = (SparkSession
         .builder
         .appName("testing")
         .getOrCreate()
    )
# Out:
# 26/07/10 19:48:24 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
data = [
    (1,"lucas", "data", 10000),
    (1,"lucas", "data", 10000),
    (2,"mateus", "operacao", 7000),
    (3,"pedro", "saude", 7000),
    (4,"jessica", "saude", None),
    (5,"sabrina", "data", 15000),
    (6,"bruno", "data", 9000),
    (7,"laryssa", "operacao", 5000),
    (8,"joilson", "saude", 7000),
    (9,"gisele", "operacao", 7500)
]

column_names = ["employee_id", "employee_name", "department_name", "salary"]



df = spark.createDataFrame(data=data, schema=column_names)

# %%
# 1. Detect nulls
from functools import reduce

condition = reduce(
    lambda x, y: x | y,
    [T.col(c).isNull() for c in df.columns]

)

df.filter(condition).show()
# Out:
# +-----------+-------------+---------------+------+
# |employee_id|employee_name|department_name|salary|
# +-----------+-------------+---------------+------+
# |          4|      jessica|          saude|  NULL|
# +-----------+-------------+---------------+------+

# %%
# 2. Drop nulls
df.dropna().show()
# Out:
# +-----------+-------------+---------------+------+
# |employee_id|employee_name|department_name|salary|
# +-----------+-------------+---------------+------+
# |          1|        lucas|           data| 10000|
# |          1|        lucas|           data| 10000|
# |          2|       mateus|       operacao|  7000|
# |          3|        pedro|          saude|  7000|
# |          5|      sabrina|           data| 15000|
# |          6|        bruno|           data|  9000|
# |          7|      laryssa|       operacao|  5000|
# |          8|      joilson|          saude|  7000|
# |          9|       gisele|       operacao|  7500|
# +-----------+-------------+---------------+------+

# %%
# 3. Fill nulls
# 4. Replace null salary with average
from pyspark.sql import functions as F
from pyspark.sql.window import Window

window_spec = Window.partitionBy("department_name")

df_filled = (
    df.withColumn(
        "salary",
        F.when(
            F.col("salary").isNull(),
            F.avg("salary").over(window_spec)
        ).otherwise(F.col("salary"))
    )
)

df_filled.show()
# Out:
# +-----------+-------------+---------------+-------+
# |employee_id|employee_name|department_name| salary|
# +-----------+-------------+---------------+-------+
# |          1|        lucas|           data|10000.0|
# |          1|        lucas|           data|10000.0|
# |          5|      sabrina|           data|15000.0|
# |          6|        bruno|           data| 9000.0|
# |          2|       mateus|       operacao| 7000.0|
# |          7|      laryssa|       operacao| 5000.0|
# |          9|       gisele|       operacao| 7500.0|
# |          3|        pedro|          saude| 7000.0|
# |          4|      jessica|          saude| 7000.0|
# |          8|      joilson|          saude| 7000.0|
# +-----------+-------------+---------------+-------+

# %%
# 5. Remove duplicates
df.dropDuplicates().show()
# Out:
# [Stage 24:==================================================>       (7 + 1) / 8]
# +-----------+-------------+---------------+------+
# |employee_id|employee_name|department_name|salary|
# +-----------+-------------+---------------+------+
# |          1|        lucas|           data| 10000|
# |          2|       mateus|       operacao|  7000|
# |          3|        pedro|          saude|  7000|
# |          5|      sabrina|           data| 15000|
# |          6|        bruno|           data|  9000|
# |          7|      laryssa|       operacao|  5000|
# |          9|       gisele|       operacao|  7500|
# |          8|      joilson|          saude|  7000|
# |          4|      jessica|          saude|  NULL|
# +-----------+-------------+---------------+------+

# %%
# 6. Trim spaces
df.select("*", T.trim(T.col("employee_name")).alias("employee_name_trimmed")).show()
# Out:
# +-----------+-------------+---------------+------+---------------------+
# |employee_id|employee_name|department_name|salary|employee_name_trimmed|
# +-----------+-------------+---------------+------+---------------------+
# |          1|        lucas|           data| 10000|                lucas|
# |          1|        lucas|           data| 10000|                lucas|
# |          2|       mateus|       operacao|  7000|               mateus|
# |          3|        pedro|          saude|  7000|                pedro|
# |          4|      jessica|          saude|  NULL|              jessica|
# |          5|      sabrina|           data| 15000|              sabrina|
# |          6|        bruno|           data|  9000|                bruno|
# |          7|      laryssa|       operacao|  5000|              laryssa|
# |          8|      joilson|          saude|  7000|              joilson|
# |          9|       gisele|       operacao|  7500|               gisele|
# +-----------+-------------+---------------+------+---------------------+

# %%
# 7. Replace values
df.fillna({"salary":0}).show()
# Out:
# +-----------+-------------+---------------+------+
# |employee_id|employee_name|department_name|salary|
# +-----------+-------------+---------------+------+
# |          1|        lucas|           data| 10000|
# |          1|        lucas|           data| 10000|
# |          2|       mateus|       operacao|  7000|
# |          3|        pedro|          saude|  7000|
# |          4|      jessica|          saude|     0|
# |          5|      sabrina|           data| 15000|
# |          6|        bruno|           data|  9000|
# |          7|      laryssa|       operacao|  5000|
# |          8|      joilson|          saude|  7000|
# |          9|       gisele|       operacao|  7500|
# +-----------+-------------+---------------+------+

# %%
# 8. Regex replace
from pyspark.sql.functions import regexp_replace
from pyspark.sql import functions as T
df.select("*", T.concat(T.col("employee_name"), T.lit("_testing")).alias("new")).withColumn("new", T.regexp_replace("new", r"_testing", "@")).show()
# Out:
# +-----------+-------------+---------------+------+--------+
# |employee_id|employee_name|department_name|salary|     new|
# +-----------+-------------+---------------+------+--------+
# |          1|        lucas|           data| 10000|  lucas@|
# |          1|        lucas|           data| 10000|  lucas@|
# |          2|       mateus|       operacao|  7000| mateus@|
# |          3|        pedro|          saude|  7000|  pedro@|
# |          4|      jessica|          saude|  NULL|jessica@|
# |          5|      sabrina|           data| 15000|sabrina@|
# |          6|        bruno|           data|  9000|  bruno@|
# |          7|      laryssa|       operacao|  5000|laryssa@|
# |          8|      joilson|          saude|  7000|joilson@|
# |          9|       gisele|       operacao|  7500| gisele@|
# +-----------+-------------+---------------+------+--------+

# %%
# 9. Standardize text

df.withColumn("standardize_name", T.lower(T.trim(T.col("employee_name")))).show()
# Out:
# +-----------+-------------+---------------+------+----------------+
# |employee_id|employee_name|department_name|salary|standardize_name|
# +-----------+-------------+---------------+------+----------------+
# |          1|        lucas|           data| 10000|           lucas|
# |          1|        lucas|           data| 10000|           lucas|
# |          2|       mateus|       operacao|  7000|          mateus|
# |          3|        pedro|          saude|  7000|           pedro|
# |          4|      jessica|          saude|  NULL|         jessica|
# |          5|      sabrina|           data| 15000|         sabrina|
# |          6|        bruno|           data|  9000|           bruno|
# |          7|      laryssa|       operacao|  5000|         laryssa|
# |          8|      joilson|          saude|  7000|         joilson|
# |          9|       gisele|       operacao|  7500|          gisele|
# +-----------+-------------+---------------+------+----------------+

# %%
# 10. Detect inconsistent rows

df.filter(T.col("salary").isNull()).show()
# Out:
# +-----------+-------------+---------------+------+
# |employee_id|employee_name|department_name|salary|
# +-----------+-------------+---------------+------+
# |          4|      jessica|          saude|  NULL|
# +-----------+-------------+---------------+------+

# %% [markdown]
# ## Modulo 9

# %% [markdown]
# 1. Write CSV
# 2. Write JSON
# 3. Write Parquet
# 4. Write partitioned Parquet
# 5. Use overwrite mode
# 6. Use append mode
# 7. Compress parquet
# 8. Save selected columns only
# 9. Create output directory
# 10. Read saved output

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

spark = SparkSession.builder.appName("testing").getOrCreate()
spark
# Out:
# 26/07/10 19:49:03 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://e02226551e85:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>exercices</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# reading datasets

df = spark.read.options(header=True, inferSchema=True).csv("datasets/employees.csv")
df.show()
# Out:
# +-----------+----------+-------------+------+----------+
# |employee_id|first_name|department_id|salary| hire_date|
# +-----------+----------+-------------+------+----------+
# |          1|     Lucas|           10|  5000|2022-01-10|
# |          2|       Ana|           20|  7000|2021-03-15|
# |          3|    Carlos|           10|  4500|2023-06-01|
# |          4|     Maria|           30|  8000|2020-08-20|
# |          5|      Joao|           20|  6200|2022-11-11|
# |          6|  Fernanda|           30|  7200|2019-07-07|
# |          7|     Pedro|           10|  5100|2024-01-05|
# |          8|     Julia|           20|  6800|2021-12-12|
# +-----------+----------+-------------+------+----------+

# %%
# 1. Write CSV
df.write.csv("datasets/employees_write.csv", header=True)

# %%
# 2. Write JSON
df.write.json("datasets/employees_write.json", lineSep=",\n", mode="overwrite")

# %%
# 3. Write Parquet
df.write.parquet("datasets/employees_write.parquet")

# %%
# 4. Write partitioned Parquet
df.write.parquet("datasets/employees_write_partitioned.parquet", partitionBy="department_id")

# %%
# 5. Use overwrite mode
df.write.parquet("datasets/employees_write_partitioned.parquet", partitionBy="department_id", mode="overwrite")

# %%
# 6. Use append mode
df.write.csv("datasets/employees_write.csv", header=True, mode="append")

# %%
# 7. Compress parquet
df.write.option("compression", "snappy").parquet("datasets/employees_compression.parquet")

# %%
spark.conf.get("spark.sql.parquet.compression.codec")
# Out:
# 'snappy'

# %%
# 8. Save selected columns only
df.select("employee_id", "first_name").write.parquet("datasets/employees_select_columns.parquet")

# %%
# 9. is unecessary

# %%
# 10. Read saved output
df_read = spark.read.csv("datasets/employees_write.csv", header=True, inferSchema=True)
df_read.show()
# Out:
# +-----------+----------+-------------+------+----------+
# |employee_id|first_name|department_id|salary| hire_date|
# +-----------+----------+-------------+------+----------+
# |          1|     Lucas|           10|  5000|2022-01-10|
# |          2|       Ana|           20|  7000|2021-03-15|
# |          3|    Carlos|           10|  4500|2023-06-01|
# |          4|     Maria|           30|  8000|2020-08-20|
# |          5|      Joao|           20|  6200|2022-11-11|
# |          6|  Fernanda|           30|  7200|2019-07-07|
# |          7|     Pedro|           10|  5100|2024-01-05|
# |          8|     Julia|           20|  6800|2021-12-12|
# |          1|     Lucas|           10|  5000|2022-01-10|
# |          2|       Ana|           20|  7000|2021-03-15|
# |          3|    Carlos|           10|  4500|2023-06-01|
# |          4|     Maria|           30|  8000|2020-08-20|
# |          5|      Joao|           20|  6200|2022-11-11|
# |          6|  Fernanda|           30|  7200|2019-07-07|
# |          7|     Pedro|           10|  5100|2024-01-05|
# |          8|     Julia|           20|  6800|2021-12-12|
# +-----------+----------+-------------+------+----------+

# %%
df_read2 = spark.read.parquet("datasets/employees_write_partitioned.parquet")
df_read2.show()
# Out:
# +-----------+----------+------+----------+-------------+
# |employee_id|first_name|salary| hire_date|department_id|
# +-----------+----------+------+----------+-------------+
# |          1|     Lucas|  5000|2022-01-10|           10|
# |          3|    Carlos|  4500|2023-06-01|           10|
# |          7|     Pedro|  5100|2024-01-05|           10|
# |          2|       Ana|  7000|2021-03-15|           20|
# |          5|      Joao|  6200|2022-11-11|           20|
# |          8|     Julia|  6800|2021-12-12|           20|
# |          4|     Maria|  8000|2020-08-20|           30|
# |          6|  Fernanda|  7200|2019-07-07|           30|
# +-----------+----------+------+----------+-------------+

# %% [markdown]
# ## Module 10

# %% [markdown]
# 1. Cache DataFrame
# 2. Persist DataFrame
# 3. Use explain()
# 4. Count partitions
# 5. Measure execution time

# %%
# 1. Cache DataFrame
df.cache()
# Out:
# DataFrame[employee_id: bigint, employee_name: string, department_name: string, salary: bigint]

# %%
# 2. Persist DataFrame
df.unpersist()
df.persist()
df.count()
# Out:
# 10

# %%
# 3. Use explain()
df.unpersist()
df_transformed = df.filter(df.salary > 0)

# 2. Persist the TRANSFORMED dataframe
df_transformed.persist()

# 3. Trigger it
df_transformed.count()

# 4. Check the plan now!
df_transformed.explain()
# Out:
# == Physical Plan ==
# InMemoryTableScan [employee_id#0L, employee_name#1, department_name#2, salary#3L]
#    +- InMemoryRelation [employee_id#0L, employee_name#1, department_name#2, salary#3L], StorageLevel(disk, memory, deserialized, 1 replicas)
#          +- *(1) Filter (isnotnull(salary#3L) AND (salary#3L > 0))
#             +- *(1) Scan ExistingRDD[employee_id#0L,employee_name#1,department_name#2,salary#3L]

# %%
# 4. Count partitions
df.rdd.getNumPartitions()
# Out:
# 8

# %%
# 5. Measure execution time
import time

start_time = time.time()
df.count()
end_time = time.time()
print(f"First run (saving to cache): {end_time - start_time:.4f} seconds")

start_time = time.time()
df.count()
end_time = time.time()
print(f"Second run (saving to cache): {end_time - start_time:.4f} seconds")
# Out:
# First run (saving to cache): 0.6275 seconds
# Second run (saving to cache): 0.5955 seconds
